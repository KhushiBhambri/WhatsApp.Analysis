# %%
import streamlit as st
import os
import re
import pandas as pd
import numpy as np
import emoji
from collections import Counter
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
#st.title('nvi nvi app')
#st.write('chal gyi oye!!')

# %%
# Extract the Date time
def date_time(s):
    pattern='^([0-9]+)(\/)([0-9]+)(\/)([0-9]+), ([0-9]+):([0-9]+)[ ]?(AM|PM|am|pm)? -'
    result=re.match(pattern, s)
    if result:
        return True
    return False 

# Extract contacts
def find_contact(s):
    s=s.split(":")
    if len(s)==2:
        return True
    else:
        return False
    
# Extract Message
def getMassage(line):
    splitline=line.split(' - ')
    datetime= splitline[0];
    date, time= datetime.split(', ')
    message=" ".join(splitline[1:])
    
    if find_contact(message):
        #print(message)
        splitmessage=message.split(": ")
        author=splitmessage[0]
        message=splitmessage[1]
    else:
        author=None
    return date, time, author, message

# %%
data=[]
conversation='Group2.txt'
with open(conversation, encoding="utf-8") as fp:
    fp.readline()
    messageBuffer=[]
    date, time, author= None, None, None
    while True:
        line=fp.readline()
        if not line:
            break
        line=line.strip()
        if date_time(line):
            if len(messageBuffer) >0:
                data.append([date, time, author, ''.join(messageBuffer)])
            messageBuffer.clear()
            date, time, author, message=getMassage(line)
            messageBuffer.append(message)
        else:
            messageBuffer.append(line)

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\bhamb\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
df=pd.DataFrame(data, columns=["Date", "Time", "contact", "Message"])
df['Date']=pd.to_datetime(df['Date'])

data=df.dropna()
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sentiments=SentimentIntensityAnalyzer()
data["positive"]=[sentiments.polarity_scores(i)["pos"] for i in data["Message"]]
data["negative"]=[sentiments.polarity_scores(i)["neg"] for i in data["Message"]]
data["neutral"]=[sentiments.polarity_scores(i)["neu"] for i in data["Message"]]

data[data['negative']>0]
# Out:
# C:\Users\bhamb\AppData\Local\Temp/ipykernel_16048/477201722.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["positive"]=[sentiments.polarity_scores(i)["pos"] for i in data["Message"]]
# C:\Users\bhamb\AppData\Local\Temp/ipykernel_16048/477201722.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["negative"]=[sentiments.polarity_scores(i)["neg"] for i in data["Message"]]
# C:\Users\bhamb\AppData\Local\Temp/ipykernel_16048/477201722.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["neutral"]=[sentiments.polarity_scores(i)["neu"] for i in data["Message"]]
#            Date      Time       contact  \
# 6    2021-08-20  11:21 pm    Khushi Cse
# 144  2021-08-20  11:35 pm   Nandini Cse
# 146  2021-08-20  11:35 pm     Mamta Cse
# 161  2021-08-20  11:36 pm     Mamta Cse
# 191  2021-08-20  11:39 pm     Mamta Cse
# ...         ...       ...           ...
# 2315 2021-06-10   3:37 pm   Nandini Cse
# 2316 2021-06-10   3:49 pm  Akanksha Cse
# 2317 2021-06-10   3:49 pm  Akanksha Cse
# 2423 2021-10-15   2:16 pm      Aman Cse
# 2499 2021-10-24   7:56 pm   Rushika Cse
#
#                                          Message  positive  negative  neutral
# 6            vese girls bhi bdda ignore kr ri he       0.0     0.263    0.737
# 144                                hard hote hai       0.0     0.412    0.588
# 146                                     Aree nah       0.0     0.583    0.417
# 161                                          Nah       0.0     1.000    0.000
# 191                                          Nah       0.0     1.000    0.000
# ...                                          ...       ...       ...      ...
# 2315  Yaar leave karna hai test ki dena hai full       0.0     0.130    0.870
# 2316                    Leave hi krdete hai yaar       0.0     0.231    0.769
# 2317                                Not worth it       0.0     0.454    0.546
# 2423            Are sorry gh2 mein most probably       0.0     0.206    0.794
# 2499                                          No       0.0     1.000    0.000
#
# [115 rows x 7 columns]

# %%
#data[data['nagative']==data['negative'].value_counts()[1]]
data[data['negative']>0].contact.value_counts().head(10)
# Out:
# Khushi Cse         41
# Nandini Cse        20
# Mamta Cse          13
# Riyanshi Cse        9
# Ishita Cse          7
# Rushika Cse         4
# Parul Cse           3
# +91 75280 12541     3
# +91 88104 75823     2
# Aman Cse            2
# Name: contact, dtype: int64

# %%
x=sum(data["positive"])
y=sum(data["negative"])
z=sum(data["neutral"])

def score(a,b,c):
    if (a>b) and (a>c):
        print("Positive ")
    if (b>a) and (b>c):
        print("Negative")
    if (c>a) and (c>b):
        print("Neutral")

score(x,y,z)
# Out:
# Neutral

# %%
df.contact.unique()
# Out:
# array([None, 'Akanksha Cse', 'Khushi Cse', 'Nandini Cse', 'Mamta Cse',
#        'Rushika Cse', 'Sheffy Cse', '+91 75085 15845', 'Shikha Cse',
#        'Aman Cse', 'Ishita Cse', 'Riyanshi Cse', '+91 81785 10488',
#        'Unnisha Cse', '+91 75280 12541', 'Sejal Cse', '+91 88104 75823',
#        'Harshita Cse', 'Parul Cse', 'Moni Cse', 'Neetu Cse Nit',
#        'Ritika Cse', 'Kumud Cse', 'Priyanka Cse', 'Sheetal Cse',
#        '+91 78889 72864', 'Mandeep Cse'], dtype=object)

# %%
media_messages = df[df['Message'] == 'Oke'].shape[0]
print(media_messages)
# Out:
# 0

# %%
def split_count(text):

    emoji_list = []
    data = regex.findall(r'\X', text)
    for word in data:
        if any(char in emoji.UNICODE_EMOJI for char in word):
            emoji_list.append(word)

    return emoji_list

# %%
import regex
df["emoji"] = df["Message"].apply(split_count)
emojis = sum(df['emoji'].str.len())
df.head(50)
# Out:
#          Date      Time       contact  \
# 0  2021-08-20  11:12 pm          None
# 1  2021-08-20  11:12 pm          None
# 2  2021-08-20  11:12 pm          None
# 3  2021-08-20  11:21 pm  Akanksha Cse
# 4  2021-08-20  11:21 pm  Akanksha Cse
# 5  2021-08-20  11:21 pm    Khushi Cse
# 6  2021-08-20  11:21 pm    Khushi Cse
# 7  2021-08-20  11:22 pm   Nandini Cse
# 8  2021-08-20  11:22 pm    Khushi Cse
# 9  2021-08-20  11:22 pm  Akanksha Cse
# 10 2021-08-20  11:22 pm   Nandini Cse
# 11 2021-08-20  11:22 pm    Khushi Cse
# 12 2021-08-20  11:22 pm  Akanksha Cse
# 13 2021-08-20  11:22 pm  Akanksha Cse
# 14 2021-08-20  11:22 pm  Akanksha Cse
# 15 2021-08-20  11:22 pm  Akanksha Cse
# 16 2021-08-20  11:22 pm   Nandini Cse
# 17 2021-08-20  11:22 pm   Nandini Cse
# 18 2021-08-20  11:22 pm   Nandini Cse
# 19 2021-08-20  11:22 pm   Nandini Cse
# 20 2021-08-20  11:22 pm  Akanksha Cse
# 21 2021-08-20  11:22 pm   Nandini Cse
# 22 2021-08-20  11:23 pm  Akanksha Cse
# 23 2021-08-20  11:23 pm    Khushi Cse
# 24 2021-08-20  11:23 pm    Khushi Cse
# 25 2021-08-20  11:23 pm    Khushi Cse
# 26 2021-08-20  11:23 pm    Khushi Cse
# 27 2021-08-20  11:23 pm    Khushi Cse
# 28 2021-08-20  11:23 pm   Nandini Cse
# 29 2021-08-20  11:24 pm   Nandini Cse
# 30 2021-08-20  11:24 pm   Nandini Cse
# 31 2021-08-20  11:24 pm  Akanksha Cse
# 32 2021-08-20  11:24 pm   Nandini Cse
# 33 2021-08-20  11:24 pm  Akanksha Cse
# 34 2021-08-20  11:24 pm  Akanksha Cse
# 35 2021-08-20  11:24 pm    Khushi Cse
# 36 2021-08-20  11:24 pm    Khushi Cse
# 37 2021-08-20  11:24 pm    Khushi Cse
# 38 2021-08-20  11:24 pm   Nandini Cse
# 39 2021-08-20  11:25 pm   Nandini Cse
# 40 2021-08-20  11:25 pm  Akanksha Cse
# 41 2021-08-20  11:25 pm   Nandini Cse
# 42 2021-08-20  11:25 pm   Nandini Cse
# 43 2021-08-20  11:25 pm    Khushi Cse
# 44 2021-08-20  11:25 pm    Khushi Cse
# 45 2021-08-20  11:25 pm   Nandini Cse
# 46 2021-08-20  11:25 pm   Nandini Cse
# 47 2021-08-20  11:26 pm    Khushi Cse
# 48 2021-08-20  11:26 pm  Akanksha Cse
# 49 2021-08-20  11:26 pm   Nandini Cse
#
#                                               Message emoji
# 0              Nandini Cse created group "Amazon wow"    []
# 1                               Nandini Cse added you    []
# 2                                 You're now an admin    []
# 3   Even if we girls were too busy to respond to a...    []
# 4                           Thoda polite krle yaar 😂😬    []
# 5                                                😂😂😂😂    []
# 6                 vese girls bhi bdda ignore kr ri he    []
# 7                          They should have responded    []
# 8                         Ik msg krne me kya jara tha    []
# 9                                       Hn wo toh hai    []
# 10                       Ak you should have responded    []
# 11                                                😂😂🌚    []
# 12                           Aree mera toh pta hi tha    []
# 13                                          Tujhe bhi    []
# 14                                      Khushi ko bhi    []
# 15                                                  🌚    []
# 16                                  Mera bhi pata tha    []
# 17                It was me and khushi the whole time    []
# 18                                                😂😂😂    []
# 19  Hum personal me baat karke group me chale jaar...    []
# 20                                           Lol okay    []
# 21                                                 😂😂    []
# 22                                Mujhe ni pta tha na    []
# 23                                                 😂😂    []
# 24                                  Ab hum enjoy krte    []
# 25                                            Jab tak    []
# 26                                         Koi ni ata    []
# 27                                                  😂    []
# 28                                                 😂😂    []
# 29           Bhai ladkiya dekh rhi hai aa ri nahi hai    []
# 30                                                 😂😂    []
# 31                                               Yess    []
# 32                              Kissi ko ni aaya kya?    []
# 33                                  Lol ye zada hogya    []
# 34                                          Aaya hoga    []
# 35                        Mamta rushika shikha sheffy    []
# 36                                      Kk toh aya he    []
# 37                                    Bakio ka ni pta    []
# 38                                      bhai sahi  me    []
# 39                        bhai priyanka bhi achhi hai    []
# 40                               Kis kis ne dekhliya?    []
# 41                                  uska bhi hua hoga    []
# 42                                            sejal??    []
# 43                                Hain vo ece vali he    []
# 44                                               Nope    []
# 45                                         apni waali    []
# 46                              west bengal ki to thi    []
# 47  Pta ni then ab tak toh baar name aya interns v...    []
# 48                               WB se kon tha bhai 😬    []
# 49                                  abhilasha, shruti    []

# %%
total_emojis_list = list([a for b in df.emoji for a in b])
emoji_dict = dict(Counter(total_emojis_list))
emoji_dict = sorted(emoji_dict.items(), key=lambda x: x[1], reverse=True)
for i in emoji_dict:
  print(i)

# %%
text = " ".join(review for review in df.Message)
print ("There are {} words in all the messages.".format(len(text)))
stopwords = set(STOPWORDS)
# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
# Display the generated image:
# the matplotlib way:
plt.figure( figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# There are 53029 words in all the messages.
